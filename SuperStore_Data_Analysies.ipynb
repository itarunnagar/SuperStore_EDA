# %%
# Import the All Necesary Library ...
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# Connect the Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Fetch the Dataset..
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Python_Sheets/Eda Projects/Fourth_Project/Sample - Superstore.csv' ,encoding = 'latin')

df.head(5)
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
# See the Overview..
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %% [markdown]
# These Data Will not Contain any missing values...Check all the columns one by one..

# %%
# See the Columns Names
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
# Check the Unique Values of all the Columns..
for unique in df :
  if df[unique].nunique() < 10 :
    print(f'New Column Name :- {df[unique].value_counts()}')
    print('\n')
    print('\n')
# Out:
# New Column Name :- Ship Mode
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: count, dtype: int64
#
#
#
#
# New Column Name :- Segment
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: count, dtype: int64
#
#
#
#
# New Column Name :- Country
# United States    9994
# Name: count, dtype: int64
#
#
#
#
# New Column Name :- Region
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: count, dtype: int64
#
#
#
#
# New Column Name :- Category
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: count, dtype: int64

# %%
# So we see the Column names Row_Id will contain only index , or sequence so we remove that columns
df.drop(columns = 'Row ID' , inplace =True)

df.head(2)
# Out:
#          Order ID Order Date   Ship Date     Ship Mode Customer ID  \
# 0  CA-2016-152156  11/8/2016  11/11/2016  Second Class    CG-12520
# 1  CA-2016-152156  11/8/2016  11/11/2016  Second Class    CG-12520
#
#   Customer Name   Segment        Country       City     State  Postal Code  \
# 0   Claire Gute  Consumer  United States  Henderson  Kentucky        42420
# 1   Claire Gute  Consumer  United States  Henderson  Kentucky        42420
#
#   Region       Product ID   Category Sub-Category  \
# 0  South  FUR-BO-10001798  Furniture    Bookcases
# 1  South  FUR-CH-10000454  Furniture       Chairs
#
#                                         Product Name   Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.96         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94         3
#
#    Discount    Profit
# 0       0.0   41.9136
# 1       0.0  219.5820

# %%
# One Again Check all the info And null values..
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       9994 non-null   object
#  1   Order Date     9994 non-null   object
#  2   Ship Date      9994 non-null   object
#  3   Ship Mode      9994 non-null   object
#  4   Customer ID    9994 non-null   object
#  5   Customer Name  9994 non-null   object
#  6   Segment        9994 non-null   object
#  7   Country        9994 non-null   object
#  8   City           9994 non-null   object
#  9   State          9994 non-null   object
#  10  Postal Code    9994 non-null   int64
#  11  Region         9994 non-null   object
#  12  Product ID     9994 non-null   object
#  13  Category       9994 non-null   object
#  14  Sub-Category   9994 non-null   object
#  15  Product Name   9994 non-null   object
#  16  Sales          9994 non-null   float64
# ...

# %%
# Change the Sales And Profit Columns Datatype into int...
df['Sales'] = df['Sales'].astype(int)
df['Profit'] = df['Profit'].astype(int)

# %%
df.head()
# Out:
#          Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region       Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# COnvet the Order Date And Ship Date Columns into A Date Format..

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Ship Date'] = pd.to_datetime(df['Ship Date'])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       9994 non-null   object
#  1   Order Date     9994 non-null   datetime64[ns]
#  2   Ship Date      9994 non-null   datetime64[ns]
#  3   Ship Mode      9994 non-null   object
#  4   Customer ID    9994 non-null   object
#  5   Customer Name  9994 non-null   object
#  6   Segment        9994 non-null   object
#  7   Country        9994 non-null   object
#  8   City           9994 non-null   object
#  9   State          9994 non-null   object
#  10  Postal Code    9994 non-null   int64
#  11  Region         9994 non-null   object
#  12  Product ID     9994 non-null   object
#  13  Category       9994 non-null   object
#  14  Sub-Category   9994 non-null   object
#  15  Product Name   9994 non-null   object
#  16  Sales          9994 non-null   int64
# ...

# %%
# Make the One More Columns To Take How Many Days taken to ship the Parcel ...
df['Days'] = df['Ship Date'] - df['Order Date']

# %% [markdown]
# #Starting Univariate Analysies

# %% [markdown]
# Convert Columns Names Order Date And Ship Date into Date Datatypes.

# %%
# So first take the Order Date Columns And Extract the Years from Order Dates Columns ..
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Ship Date'] = pd.to_datetime(df['Ship Date'])


# Create A new Columns With Names Order Year And Ship Years..
df['Order Year'] = df["Order Date"].dt.year
df['Ship Year'] = df["Ship Date"].dt.year

# %%
# Check the Year Wise Order Trends..
plt.figure(figsize = (6 , 4))
ax = sns.countplot(x = 'Order Year' , data = df )
plt.title('Year Wise Order')
plt.xlabel('Years')
plt.ylabel('Numbers of Orders')

# For Numbers in the Bars
for i in ax.containers :
  ax.bar_label(i)

# To Save a Figure or Pics..
# plt.savefig('Year_Wise_Order.jpg')

# %% [markdown]
# Obervation :- We can Years Wise orders numbers was also increases..

# %%
# To see Numbers of Orders Shiped by which company ..
plt.figure(figsize = (6, 5))
ax = sns.countplot(x = 'Ship Mode' , data = df)
plt.title('Shipped By Company')
plt.xlabel('Company Names ')
plt.ylabel('Numbers of Orders')

for unique in ax.containers :
  ax.bar_label(unique)

# To Save a Figure or Pics..
plt.savefig('Shipped_By_Company.jpg')

# %% [markdown]
# Observations :- <br>
# Mostly orders are shipped by Standard Class Company and then Second Class After that First Class And In the Last least orders was shipped by Same Day Company

# %%
# Upper Sames Things Seen by the Pie Chart..
plt.figure(figsize = (7, 4))
plt.pie(df['Ship Mode'].value_counts().values , labels = df['Ship Mode'].value_counts().index
        , autopct = '%.1f%%' ,  counterclock=False, startangle=180)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)
plt.title('Shipped By Company')
plt.savefig('Shipped_By_Company.jpg')

# %% [markdown]
# Obervations :- <br>
# 59.7 % Order are Shipped By Standard Class , 19.5% Order are Shipped By Second Class , 15.4% Order are Shipped by First Class and Same Day Will Shipped 5.4% Orders.

# %%
# See the Order  COunts By Segment Wise
ax = sns.countplot(x = 'Segment' , data = df)
plt.title('Segment Wise Orders')
plt.xlabel('Customer Segment')
plt.ylabel('Numbers of  Orders')

for unique in ax.containers :
  ax.bar_label(unique)

plt.savefig('Consumer_Segment_bar.jpg')

# %% [markdown]
# Observation :- <br>
# Consumenrs Segment will order the Most after that Corporate segmenet and the last home office segment will make orders..

# %%
plt.figure(figsize = (7,5))
plt.pie(df['Segment'].value_counts().values ,labels = df['Segment'].value_counts().index , autopct = '%.2f%%')
plt.title("Consumer Segment" , fontdict= {'fontweight' : 800})
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)
plt.savefig('Consumer_Segment_pie.jpg')

# %% [markdown]
# Observation :- <br>
# 51.9 % Order are Come from Consumer Segment , 30.2% Order are Come from Corporate Segment , And 17.84% Order are Come from Home Office Segments

# %%
# So these All Data Related to United States Country So we Also remove that columns..
# Because on country basis we cant do any further analysies so we remove the  Country Columns from the Given Dataset..
df.drop(columns = 'Country' ,axis = 1 ,  inplace = True )

# %%
# Now move Further city columns we check now..
df.City.value_counts()

# So instead of city columns we can check state columns because city columns will contain total 531 UNique Values...
df.City.nunique()
# Out:
# 531

# %%
# # See the Numbers of Orders State Wise
# First of these will also contain 49 Unique Values So we sort out or filter out the Data BAsed on some Conditions...

Higher_order_State = df['State'].value_counts().reset_index().rename(columns = {'count' : 'Numbers of Orders'})
States  = Higher_order_State[Higher_order_State['Numbers of Orders'] > 200].sort_values(by = 'Numbers of Orders' , ascending = True)
States
# Change the Figure Size
# plt.figure(figsize =(10 , 5))

# # Making the Bar Plot For the  Upper Data...
# plt.bar(x = States['State'] ,height = States['Numbers of Orders'] )
# plt.title('State Wise Orders')
# plt.xlabel('States')
# plt.ylabel('Numbers of  Orders')
# plt.xticks(rotation = 90)

# # To Save a Figure or Pics..
# plt.savefig('State_Wise_Orders.jpg')

# plt.show()
# Out:
#              State  Numbers of Orders
# 10         Arizona                224
# 11        Virginia                224
# 9   North Carolina                249
# 8         Michigan                255
# 7          Florida                383
# 6             Ohio                469
# 5         Illinois                492
# 4       Washington                506
# 3     Pennsylvania                587
# 2            Texas                985
# 1         New York               1128
# 0       California               2001

# %% [markdown]
# Observation :- <br>
# Highest Order Are coming from California , New York and Then Taxas...These are top 3 State Where order Numbers was High..

# %%
# Bar Plot for the Region Wise Percantages...
ax = sns.countplot(x = 'Region' , data = df , width = 0.5)
plt.title('Region Wise Orders')
plt.xlabel('Region')
plt.ylabel('Numbers of  Orders')

# Values Above the Bars
for unique in ax.containers :
  ax.bar_label(unique)

# To Save a Figure or Pics..
plt.savefig('Region_Wise_Orders.jpg')

plt.show()

# %% [markdown]
# Observations :- <br>
# Most Order are Coming are from West Region , then East Region , Central Region and then the least order are cominmg from South...

# %%
# Then See the Category Columns..
# Make the Pie Plot..
plt.figure(figsize = (7,4))
plt.pie(df['Category'].value_counts().values
, labels = df['Category'].value_counts().index , autopct = '%0.2f%%')
plt.title("Category Wise Order Percantages")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)
plt.savefig('Category_Wise_Order.jpg')
plt.show()

# %% [markdown]
# Observation :- <br>
# Mostly order are coming from Office Supply with 60.30% , Furniture will get 21.22% Order and Remainiong order are coming from Technology Percantages.

# %%
# See the Sub Category Columns..
plt.figure(figsize = (10,8))
ax = sns.countplot(x = 'Sub-Category' , data = df , order = df['Sub-Category'].value_counts().index)
plt.title('Sub Category Wise Orders')
plt.xlabel('Sub Category')
plt.ylabel('Numbers of Orders')
plt.xticks(rotation = 90)

# For  PPutting the Numbers
for unique in ax.containers :
  ax.bar_label(unique)

# To Save a Figure or Pics..
plt.savefig('Sub_Category_Wise_Orders.jpg')

plt.show()

# %% [markdown]
# Observation :- <br>
# MOst Order are coming from Binders , paper and then Furnishig and remaining you can see on the  Chart...

# %% [markdown]
# # Starting Bi-Variate Analysies

# %%
# Numbers  of Order Per Category And Also Year Wise
ax = sns.countplot(x = 'Order Year' , data = df , hue = 'Category')

plt.title('Category Wise Order Per Year')
plt.xlabel('Years')
plt.ylabel('Numbers of Orders')

for unique in ax.containers :
  ax.bar_label(unique)

plt.savefig('Category_Wise_Order_Per_Year.jpg')

# %% [markdown]
# As We Know Year Wise All Three Categories will get more orders but Office Supplies Category will get more numbers of Orders...

# %%
# Sales Per Years..
sales_per_years = df.groupby('Order Year')['Sales'].sum().reset_index()


plt.figure(figsize = (4, 4))
plt.bar(x = sales_per_years['Order Year'] , height = sales_per_years['Sales'] , data = sales_per_years , width = 0.5)
plt.title('Sales Per Years')
plt.xlabel('Years')
plt.ylabel('Sales')

plt.savefig('Sales_Per_Years.jpg')
plt.show()

# %% [markdown]
# Observation :- <br>
# So we see our sales will increases year by years but in the 2014 The Sales was higher as compared to it Next Years...Else Sales Was Increases Year By Year

# %%
# Profit Per Years..
per_per_year = df.groupby('Order Year')['Profit'].sum().reset_index()

# Make the Bar Plot...
plt.figure(figsize = (4, 4))
plt.bar(x = 'Order Year' , height = 'Profit' , data = per_per_year , width = 0.5)
plt.title('Profit Per Years')
plt.xlabel('Years')
plt.ylabel('Profit')

plt.savefig('Profit_Per_Years.jpg')
plt.show()

# %% [markdown]
# Observation :- <br>
# Per Year Our Profit Increases Simultaneoutly

# %%
# Total Stock Sales Per Years...
stock_sales_per_year = df.groupby('Order Year')['Quantity'].sum() .reset_index()

plt.figure(figsize = (4, 4))
plt.bar(x = stock_sales_per_year['Order Year'] , height = stock_sales_per_year['Quantity'] , data = stock_sales_per_year , width = 0.5)
plt.title('Stock Sales Per Years')
plt.xlabel('Years')
plt.ylabel('Stock Sales')

plt.savefig('Stock_Sales_Per_Years.jpg')
plt.show()

# %% [markdown]
# So we see the Stock Quantity was also increasing year by year that was so obivious

# %%
# Total Stock Sales in Each Category.
category_wise_stock = df.groupby('Category')['Quantity'].sum().sort_values(ascending = False)

plt.figure(figsize = (4, 4))

# Make the Bar Chart...
plt.bar(x = category_wise_stock.index , height = category_wise_stock.values , data = category_wise_stock  )
plt.title('Category Wise Stock Sales')
plt.xlabel('Category')
plt.ylabel('Stock Sales')
plt.savefig('Category Wise Stock Sales')
plt.show()

# %% [markdown]
# Obersvation :- <br>
# Mostly Stock was selled by Office Supply category and then Furniture and the least quantity was sold in Technology

# %%
# Ship Mode Year Wise
sns.countplot(x = 'Ship Year' , data = df , hue = 'Ship Mode')
plt.title('Ship Mode Year Wise')
plt.xlabel('Years')
plt.ylabel('Numbers of Orders')
plt.savefig('Ship_Mode_Year_Wise.jpg')
plt.show()

# %% [markdown]
# Observation :- <br>
# So we see from the Starting year we shipped our mostly order from Standard Class , Second Class and then First Class and least order was shipped by Same Dat Shipping Company Class

# %%
# Segment Wise Sales
Segment_Wise_Sales = df.groupby('Segment')['Sales'].sum().reset_index()

plt.figure(figsize = (4, 4))
plt.bar(x = Segment_Wise_Sales['Segment'] , height= Segment_Wise_Sales['Sales'] , data = Segment_Wise_Sales)
plt.title('Segment Wise Sales')
plt.xlabel('Segment')
plt.ylabel('Sales')
plt.savefig('Segment_Wise_Sales.jpg')
plt.show()

# %% [markdown]
# Obervation :- <br>
# Mostly Sales are coming from a Consumer Segment , and then Corporate Segment and then the least order was come from a Home Office Segment..

# %%
# Segment Wise Profit
seg_wise_profit = df.groupby('Segment')['Profit'].sum().reset_index()

plt.figure(figsize = (4, 4))
plt.bar(x = seg_wise_profit['Segment'] , height = seg_wise_profit['Profit'] , data = seg_wise_profit)
plt.title('Segment Wise Profit')
plt.xlabel('Segment')
plt.ylabel('Profit')
plt.savefig('Segment_Wise_Profit.jpg')
plt.show()

# %% [markdown]
# Observation :- <br>
# Mostly profit are coming from a Consumer Segment then Corporate Segment and then least profit was coming from a Home Office Segment

# %%
# Category Wise Sales
sales_by_cat = df.groupby('Category')['Sales'].sum().reset_index()

plt.bar(x = sales_by_cat['Category'] , height = sales_by_cat['Sales'] , data = sales_by_cat)
plt.title('Category Wise Sales')
plt.xlabel('Category')
plt.ylabel('Total Sales')
plt.savefig('Category Wise Sales')
plt.show()

# %% [markdown]
# Observation :- <br>
# Almost Each category will give the same sales...

# %%
# Category Wise Profit
sales_by_cat = df.groupby('Category')['Profit'].sum().reset_index()

plt.bar(x = sales_by_cat['Category'] , height = sales_by_cat['Profit'] , data = sales_by_cat)
plt.title('Category Wise Sales')
plt.xlabel('Category')
plt.ylabel('Total Sales')
plt.savefig('Category Wise Profit')
plt.show()

# %% [markdown]
# Obwervation :- <br>
# But we can see the all category will get the same level of sales but at when we see the category wise profit we see Technology category will get the highest profit , office supply will get the less profit as compared to Technology Categroy and Furniture will get the least profit

# %%
# Sales Vs Profit Per Year
# sales_vs_profit = df.groupby('Order Year')[['Sales' , 'Profit']].sum().reset_index()
# plt.plot(sales_vs_profit['Order Year'] , sales_vs_profit['Sales'] , label = 'Sales')
# plt.plot(sales_vs_profit['Order Year'] , sales_vs_profit['Profit'] , label = 'Profit')
# plt.savefig('Sales_VS_Profit')

sales_per_years = df.groupby('Order Year')['Sales'].sum().reset_index()
plt.figure(figsize = (6, 5))
plt.bar(x = sales_per_years['Order Year'] , height = sales_per_years['Sales'] , data = sales_per_years , width = 0.5)
plt.title('Sales Per Years')
plt.xlabel('Years')
plt.ylabel('Sales')
plt.savefig('Sales Per Year')

profit_per_years = df.groupby('Order Year')['Profit'].sum().reset_index()
plt.figure(figsize = (6, 5))
plt.bar(x = profit_per_years['Order Year'] , height = profit_per_years['Profit'] , data = profit_per_years , width = 0.5)
plt.title('Profit Per Years')
plt.xlabel('Years')
plt.ylabel('Profit')
plt.savefig('Profit Per Year')

# %% [markdown]
# As compared to our sales our profit was very less we also have to increase our profit margin as well because as we seen if we sells  450000 items then we only got 40000Profit That not a good  for  us

# %%
# Make the New Columns..
new_df = df['Days'].sort_values().reset_index()
plt.figure(figsize = (10, 5))
ax = sns.countplot(y = new_df['Days'] , data = new_df )
plt.title("Time Take to Shipped")
plt.xlabel('Numbers of Orders')
plt.ylabel('Days')

for unique in ax.containers :
  ax.bar_label(unique)

plt.show()

# %% [markdown]
# Mostly Order will take 4 Days to Shiip  , then 5 Days And After Than 6 Days Will ALso take to ship the orders and that will not give the good impact to the customer ..Because if order take 6 Days to Only for ship and then it will also take 4/5 Days to deliver so we haive reduced our shipping time as well

# %% [markdown]
# # Overall Summary
# ##### The analysis reveals positive growth trends in orders, sales, and profit over the years. The Consumer segment is the most significant contributor to both sales and profit. Geographically, California, New York, and Texas are the top-performing states. Office Supplies dominate in terms of order volume and stock sales, but Technology leads in profitability. Standard Class shipping is the most utilized shipping method. This comprehensive insight can guide strategic decisions to further enhance performance and address areas with potential for improvement.
